# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Bakery.csv")

# %%
df.head()
# Out:
#    TransactionNo          Items          DateTime  Daypart  DayType  Quantity  \
# 0              1          Bread  30-10-2016 09:58  Morning  Weekend         5
# 1              2   Scandinavian  30-10-2016 10:05  Morning  Weekend         1
# 2              2   Scandinavian  30-10-2016 10:05  Morning  Weekend         1
# 3              3  Hot chocolate  30-10-2016 10:07  Morning  Weekend         4
# 4              3            Jam  30-10-2016 10:07  Morning  Weekend         3
#
#    Price
# 0     35
# 1     43
# 2     43
# 3     97
# 4     96

# %%
df.columns
# Out:
# Index(['TransactionNo', 'Items', 'DateTime', 'Daypart', 'DayType', 'Quantity',
#        'Price'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# TransactionNo    0
# Items            0
# DateTime         0
# Daypart          0
# DayType          0
# Quantity         0
# Price            0
# dtype: int64

# %%
df.duplicated(keep=False).sum()
# Out:
# np.int64(694)

# %%
df.drop_duplicates(keep="first").reset_index(drop=True)
# Out:
#        TransactionNo          Items          DateTime    Daypart  DayType  \
# 0                  1          Bread  30-10-2016 09:58    Morning  Weekend
# 1                  2   Scandinavian  30-10-2016 10:05    Morning  Weekend
# 2                  3  Hot chocolate  30-10-2016 10:07    Morning  Weekend
# 3                  3            Jam  30-10-2016 10:07    Morning  Weekend
# 4                  3        Cookies  30-10-2016 10:07    Morning  Weekend
# ...              ...            ...               ...        ...      ...
# 20154           9682         Coffee  04-09-2017 14:32  Afternoon  Weekend
# 20155           9682            Tea  04-09-2017 14:32  Afternoon  Weekend
# 20156           9683         Coffee  04-09-2017 14:57  Afternoon  Weekend
# 20157           9683         Pastry  04-09-2017 14:57  Afternoon  Weekend
# 20158           9684      Smoothies  04-09-2017 15:04  Afternoon  Weekend
#
#        Quantity  Price
# 0             5     35
# 1             1     43
# 2             4     97
# 3             3     96
# 4             3     72
# ...         ...    ...
# 20154         1     43
# 20155         3     39
# 20156         2     43
# 20157         4     54
# 20158         1     99
#
# [20159 rows x 7 columns]

# %%
revenue = df["Price"] * df["Quantity"]
print(revenue)
total_revenue = revenue.sum()
print("total_revenue:", total_revenue)
# Out:
# 0        175
# 1         43
# 2         43
# 3        388
# 4        288
#         ...
# 20502     43
# 20503    117
# 20504     86
# 20505    216
# 20506     99
# Length: 20507, dtype: int64
# total_revenue: 3139967

# %%
product_summary = df.groupby("Items").agg(
    Total_Quantity=("Quantity", "sum"),
    Total_Revenue=("Price", "sum")
)
print(product_summary)
# Out:
#                           Total_Quantity  Total_Revenue
# Items
# Adjustment                             5             96
# Afternoon with the baker             146           1496
# Alfajores                           1093          33948
# Argentina Night                       23            273
# Art Tray                             113           2622
# ...                                  ...            ...
# Tshirt                                69           1764
# Valentine's card                      40            819
# Vegan Feast                           47            624
# Vegan mincepie                       157           2376
# Victorian Sponge                      21            273
#
# [94 rows x 2 columns]

# %%
product_summary = product_summary.sort_values("Total_Revenue", ascending=False)

# %%
print(product_summary)
# Out:
#                 Total_Quantity  Total_Revenue
# Items
# Coffee                   16376         235253
# Bread                     9959         116375
# Hot chocolate             1786          57230
# Tea                       4218          55965
# Cake                      3044          50225
# ...                        ...            ...
# Gift voucher                 4             59
# Olum & polenta               4             55
# Polenta                      5             52
# The BART                     3             44
# Chicken sand                 1             33
#
# [94 rows x 2 columns]

# %%
print(product_summary.head(10))  # top 10 products by revenue
# Out:
#                Total_Quantity  Total_Revenue
# Items
# Coffee                  16376         235253
# Bread                    9959         116375
# Hot chocolate            1786          57230
# Tea                      4218          55965
# Cake                     3044          50225
# Pastry                   2617          46224
# Cookies                  1619          38880
# Alfajores                1093          33948
# Brownie                  1127          31457
# Toast                     966          30528

# %%
d1 = df.copy()

# %%
d1.isnull().sum()
# Out:
# TransactionNo    0
# Items            0
# DateTime         0
# Daypart          0
# DayType          0
# Quantity         0
# Price            0
# dtype: int64

# %%
df.head()
# Out:
#    TransactionNo          Items          DateTime  Daypart  DayType  Quantity  \
# 0              1          Bread  30-10-2016 09:58  Morning  Weekend         5
# 1              2   Scandinavian  30-10-2016 10:05  Morning  Weekend         1
# 2              2   Scandinavian  30-10-2016 10:05  Morning  Weekend         1
# 3              3  Hot chocolate  30-10-2016 10:07  Morning  Weekend         4
# 4              3            Jam  30-10-2016 10:07  Morning  Weekend         3
#
#    Price
# 0     35
# 1     43
# 2     43
# 3     97
# 4     96

# %%
df.iloc[1:5,1:5] #iloc is index based slicing (custom range of table)
# Out:
#            Items          DateTime  Daypart  DayType
# 1   Scandinavian  30-10-2016 10:05  Morning  Weekend
# 2   Scandinavian  30-10-2016 10:05  Morning  Weekend
# 3  Hot chocolate  30-10-2016 10:07  Morning  Weekend
# 4            Jam  30-10-2016 10:07  Morning  Weekend

# %%
d1.duplicated().sum()
# Out:
# np.int64(348)

# %%
df.duplicated().sum()
# Out:
# np.int64(348)

# %%
d2 = pd.read_csv("/content/Bakery.csv")

# %%
d2.duplicated().sum()
# Out:
# np.int64(348)

# %%
d2.drop_duplicates(keep="first").reset_index(drop=True)
# Out:
#        TransactionNo          Items          DateTime    Daypart  DayType  \
# 0                  1          Bread  30-10-2016 09:58    Morning  Weekend
# 1                  2   Scandinavian  30-10-2016 10:05    Morning  Weekend
# 2                  3  Hot chocolate  30-10-2016 10:07    Morning  Weekend
# 3                  3            Jam  30-10-2016 10:07    Morning  Weekend
# 4                  3        Cookies  30-10-2016 10:07    Morning  Weekend
# ...              ...            ...               ...        ...      ...
# 20154           9682         Coffee  04-09-2017 14:32  Afternoon  Weekend
# 20155           9682            Tea  04-09-2017 14:32  Afternoon  Weekend
# 20156           9683         Coffee  04-09-2017 14:57  Afternoon  Weekend
# 20157           9683         Pastry  04-09-2017 14:57  Afternoon  Weekend
# 20158           9684      Smoothies  04-09-2017 15:04  Afternoon  Weekend
#
#        Quantity  Price
# 0             5     35
# 1             1     43
# 2             4     97
# 3             3     96
# 4             3     72
# ...         ...    ...
# 20154         1     43
# 20155         3     39
# 20156         2     43
# 20157         4     54
# 20158         1     99
#
# [20159 rows x 7 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(348)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'], dayfirst=True)
df['Sales'] = df['Quantity'] * df['Price']

# %%
top_items = (
    df.groupby('Items')['Quantity']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure()
top_items.plot(kind='bar')
plt.title('Top 10 Selling Items by Quantity')
plt.xlabel('Item')
plt.ylabel('Quantity Sold')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
sales_daypart = df.groupby('Daypart')['Sales'].sum()

plt.figure()
sales_daypart.plot(kind='bar')
plt.title('Sales by Daypart')
plt.xlabel('Daypart')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %%
daily_sales = df.groupby(df['DateTime'].dt.date)['Sales'].sum()

plt.figure()
daily_sales.plot()
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %%
daytype_sales = df.groupby('DayType')['Sales'].sum()

plt.figure()
daytype_sales.plot(kind='bar')
plt.title('Weekday vs Weekend Sales')
plt.xlabel('Day Type')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %%
total_sales = df['Sales'].sum()
top_product = top_items.index[0]
best_daypart = sales_daypart.idxmax()

total_sales, top_product, best_daypart
# Out:
# (np.int64(3094674), 'Coffee', 'Afternoon')
